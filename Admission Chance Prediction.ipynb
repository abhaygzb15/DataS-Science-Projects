# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data OverView

# %%
df=pd.read_csv('Admission Chance.csv')
df
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df.tail()
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %% [markdown]
# GRE Scores (290 to 340)
# TOEFL Scores (92 to 120)
# University Rating (1 to 5)
# Statement of Purpose (1 to 5)
# Letter of Recommendation Strength (1 to 5)
# Undergraduate CGPA (6.8 to 9.92)
# Research Experience (0 or 1)
# Chance of Admit (0.34 to 0.97)

# %%
df.shape
# Out:
# (400, 9)

# %%
df.columns
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df['University Rating'].value_counts()
# Out:
# University Rating
# 3    133
# 2    107
# 4     74
# 5     60
# 1     26
# Name: count, dtype: int64

# %%
df['Research'].value_counts()
# Out:
# Research
# 1    219
# 0    181
# Name: count, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df.nunique()
# Out:
# Serial No            400
# GRE Score             49
# TOEFL Score           29
# University Rating      5
#  SOP                   9
# LOR                    9
# CGPA                 168
# Research               2
# Chance of Admit       60
# dtype: int64

# %%
df.isnull()
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0        False      False        False              False  False  False
# 1        False      False        False              False  False  False
# 2        False      False        False              False  False  False
# 3        False      False        False              False  False  False
# 4        False      False        False              False  False  False
# ..         ...        ...          ...                ...    ...    ...
# 395      False      False        False              False  False  False
# 396      False      False        False              False  False  False
# 397      False      False        False              False  False  False
# 398      False      False        False              False  False  False
# 399      False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False             False
# 1    False     False             False
# 2    False     False             False
# 3    False     False             False
# 4    False     False             False
# ..     ...       ...               ...
# 395  False     False             False
# 396  False     False             False
# 397  False     False             False
# 398  False     False             False
# 399  False     False             False
#
# [400 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Serial No            0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
#  SOP                 0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#         Serial No   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No          400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4    SOP               400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB

# %% [markdown]
# ## Data Visualisation

# %%
df
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
plt.figure(figsize=(15,4))
sns.displot(df['GRE Score'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['GRE Score'],y=df['Chance of Admit '],hue=df['Research'])
plt.show()

# %%
sns.countplot(x=df['University Rating'])
plt.show()

# %%
correlation = df['University Rating'].corr(df['Chance of Admit '])
print(correlation)
# Out:
# 0.7112502503917224

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='CGPA', y='Chance of Admit ', data=df, scatter_kws={'s':10}, line_kws={'color':'red'})
plt.title('CGPA vs Chance of Admit')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Research', y='Chance of Admit ', data=df)
plt.title('Effect of Research on Chance of Admission')
plt.xlabel('Research (0 = No, 1 = Yes)')
plt.ylabel('Chance of Admit')
plt.show()

# %% [markdown]
# # Admission Chance Prediction

# %%
df
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
X=df.drop(columns=['Serial No','Chance of Admit '])
Y=df['Chance of Admit ']

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  Research
# 0          337          118                  4   4.5   4.5  9.65         1
# 1          324          107                  4   4.0   4.5  8.87         1
# 2          316          104                  3   3.0   3.5  8.00         1
# 3          322          110                  3   3.5   2.5  8.67         1
# 4          314          103                  2   2.0   3.0  8.21         0
# ..         ...          ...                ...   ...   ...   ...       ...
# 395        324          110                  3   3.5   3.5  9.04         1
# 396        325          107                  3   3.0   3.5  9.11         1
# 397        330          116                  4   5.0   4.5  9.45         1
# 398        312          103                  3   3.5   4.0  8.78         0
# 399        333          117                  4   5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
Y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
# train and test dataset
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (320, 7) (80, 7) (320,) (80,)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model_LR=LinearRegression()
model_LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model_LR.coef_
# Out:
# array([ 0.00152724,  0.00257075,  0.00169322, -0.00026637,  0.02233956,
#         0.1321521 ,  0.02352028])

# %%
model_LR.intercept_
# Out:
# -1.264839073545969

# %%
print("Training Score : ",model_LR.score(X_train,Y_train))
print("Test Score : ",model_LR.score(X_test,Y_test))
# Out:
# Training Score :  0.8199920102142904
# Test Score :  0.7246761028295703

# %%
y_predicted=model_LR.predict(X_test)
y_predicted
# Out:
# array([0.78212379, 0.6943934 , 0.71157252, 0.87999368, 0.62143577,
#        0.65220199, 0.74402724, 0.72527884, 0.73090274, 0.70742897,
#        0.67545648, 0.91038653, 0.53580059, 0.7744113 , 0.89869856,
#        0.47548594, 0.73024811, 0.73111697, 0.75390534, 0.97710642,
#        0.73670858, 0.82739274, 0.84041363, 0.90194788, 0.82483179,
#        0.55583645, 0.62445329, 0.85014285, 1.00070898, 0.85830424,
#        0.8529793 , 0.52403052, 0.63589741, 0.84516489, 0.81162799,
#        0.49491484, 0.93731556, 0.73898995, 0.69915458, 0.96423623,
#        0.67341926, 0.67793502, 0.72679895, 0.69770065, 0.46483297,
#        0.74829845, 0.69117253, 0.85614422, 0.67527607, 0.48457131,
#        0.76990645, 0.78890917, 0.95807957, 0.79094507, 0.79174471,
#        0.69594179, 0.454834  , 0.86102837, 0.70642301, 0.67537593,
#        0.953609  , 0.86689336, 0.6091155 , 0.64163391, 0.64712839,
#        0.56365127, 0.52947643, 0.77877424, 0.61834945, 0.69692923,
#        0.62456671, 0.69161279, 0.78870304, 0.50519652, 0.65014283,
#        0.60114378, 0.71377456, 0.73879605, 0.66735077, 0.62443166])

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(Y_test,y_predicted)
# Out:
# 0.08278931973085091

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
model_RF=RandomForestRegressor()
model_RF.fit(X_train,Y_train)
print("Training Score : ",model_RF.score(X_train,Y_train))
print("Test Score : ",model_RF.score(X_test,Y_test))
# Out:
# Training Score :  0.9688583335320817
# Test Score :  0.6663644573973676

# %%
y_predicted=model_RF.predict(X_test)
y_predicted
# Out:
# array([0.7653, 0.6711, 0.7015, 0.8972, 0.6186, 0.6106, 0.75  , 0.7032,
#        0.7512, 0.7263, 0.6766, 0.9218, 0.5678, 0.7889, 0.9179, 0.4781,
#        0.7634, 0.7386, 0.7638, 0.9504, 0.6947, 0.8196, 0.8387, 0.8984,
#        0.8331, 0.552 , 0.6678, 0.8023, 0.9616, 0.897 , 0.8589, 0.5161,
#        0.667 , 0.8935, 0.8071, 0.4987, 0.9439, 0.7864, 0.6967, 0.9407,
#        0.6288, 0.7002, 0.7044, 0.6909, 0.4662, 0.761 , 0.6859, 0.8227,
#        0.6812, 0.505 , 0.7575, 0.7921, 0.9418, 0.7439, 0.8257, 0.7242,
#        0.4397, 0.8546, 0.6938, 0.6944, 0.9613, 0.9209, 0.6053, 0.6293,
#        0.6264, 0.5718, 0.5234, 0.7636, 0.628 , 0.6147, 0.654 , 0.7046,
#        0.7827, 0.49  , 0.6406, 0.5642, 0.7041, 0.7732, 0.7018, 0.6144])

# %%
mean_absolute_percentage_error(Y_test,y_predicted)
# Out:
# 0.09327976933362586
